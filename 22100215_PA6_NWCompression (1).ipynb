# %%
from __future__ import absolute_import
from __future__ import print_function
import os
import itertools
import numpy as np
np.random.seed(1337)  # for reproducibility

from tensorflow.keras import regularizers
from tensorflow.keras.datasets import cifar10,mnist,fashion_mnist,cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,Lambda
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD, Adadelta, Adagrad
import tensorflow.keras.backend as K
from tensorflow.python.framework.ops import Tensor
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Layer,Flatten,BatchNormalization
from tensorflow.python.keras.engine.input_layer import InputLayer
from tensorflow.keras.constraints import max_norm,MinMaxNorm
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.callbacks import ModelCheckpoint
#tf.compat.v1.disable_eager_execution()

# %% [markdown]
# Run this cell if you want to use keras sergeon for complete removel of filters

# %%
#use while filter pruning via Keras-Sergeon
! pip uninstall -y tensorflow
! pip uninstall -y tf-nightly

! pip install tensorflow-gpu==2.0.0-beta1
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tf-nightly as it is not installed.
# Requirement already satisfied: tensorflow-gpu==2.0.0-beta1 in /usr/local/lib/python3.7/dist-packages (2.0.0b1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.36.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.12.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.19.5)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.32.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.3.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.1)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0.dev2019060501)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.2.0)
# Requirement already satisfied: tb-nightly<1.14.0a20190604,>=1.14.0a20190603 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.14.0a20190603)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.12.4)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (54.2.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.10.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.7.4.3)

# %%
def normalize(X_train,X_test):
  mean = np.mean(X_train,axis=(0,1,2,3))
  std = np.std(X_train, axis=(0, 1, 2, 3))
  print(mean)
  print(std)
  X_train = (X_train-mean)/(std+1e-7)
  X_test = (X_test-mean)/(std+1e-7)
  return X_train, X_test

# %%
#Data Processing
batch_size = 128
num_classes = 10
epochs = 100
data_augmentation = True
num_predictions = 20
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_train = np.pad(x_train, ((0,0),(2,2),(2,2),(0,0)), 'constant')
x_test = np.pad(x_test, ((0,0),(2,2),(2,2),(0,0)), 'constant')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train, x_test = normalize(x_train, x_test)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
steps_per_epoch = x_train.shape[0]//batch_size
# Out:
# 25.50944
# 70.18035
# x_train shape: (60000, 32, 32, 1)
# 60000 train samples
# 10000 test samples

# %%
#Data Generator
batch_size = 128
maxepoches = 20
learning_rate = 0.01
lr_decay = 1e-6
lr_drop = 5


def lr_scheduler(epoch):
    if(epoch<250):
        return learning_rate * (0.5 ** (epoch // lr_drop))
    else:
        return learning_rate * (0.4 ** (epoch // lr_drop))
reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)


#data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False)  # randomly flip images
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %%
#VGG-16
model = Sequential()
weight_decay = 0.005
x_shape = (32,32,1)

# model.add(UpSampling2D(size=(2, 2),input_shape=self.x_shape))
model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay),input_shape=x_shape))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))

model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))

model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))



model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#model.add(Dropout(0.4))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))


model.add(Flatten())
model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())


#model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 64)        640
# _________________________________________________________________
# activation_15 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_16 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_19 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_21 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_22 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_23 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_24 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_25 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_26 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_27 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_28 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_29 (Activation)   (None, 10)                0
# =================================================================
# Total params: 15,000,266
# Trainable params: 14,990,794
# Non-trainable params: 9,472
# _________________________________________________________________
# None

# %% [markdown]
# In this step we will create a custom regularizer using "tf.keras.regularizers.Regularizer" which will apply waighted L1 regularization on pruning tensor vectors. The regularization would be waighted based on the size of pruning tensor vector size which will be passed through FPruningL layer.

# %%
#Beta Regularizer
class b_reg(tf.keras.regularizers.Regularizer):

    def __init__(self, b_scalef):
        self.b_scalef = K.cast_to_floatx(b_scalef)

    def __call__(self, weight_matrix):
      return K.sum(K.abs(weight_matrix)) * self.b_scalef

    def get_config(self): 
      return {'Factor': float(self.b_scalef)}

# %% [markdown]
# # Task 1
#
# In this step we will create a custom tf layer for pruning tensor vectors. The layer will take size as initializing input and initialize a 1-D tensor of trainable weights from that size. These 1-D tensors will be initialized from ones and we will apply the above created regularization to push these tensors towards zero.
# These custom layers will be placed as gates infront of all CONV layers. The input of these layers will be the output of CONV layers and the output of these layers would be a product of input wilth the 1-D tensor vector.
#
# For this task you have to write the call function of FpruningL custom layer. call function is the function that will be called during runtime. The output of previous layer will be passed to this function as parameter(in this case 'x'), you have to return the product of 1-D tensor('kernel1') and previous layer output from this function.

# %%
#Filter pruning lembda layer
class FPruningL(Layer):
    def __init__(self, size = 0.0, **kwargs):
        super(FPruningL, self).__init__(**kwargs)
        self.size = size
    def build(self, input_shape):
        self.kernel1 = self.add_weight(constraint=MinMaxNorm(min_value=0.0, max_value=1.0, rate=1.0, axis=0),
                                       name='kernel1', shape=( 1, 1, 1, self.size), 
                                       regularizer=b_reg(1/(self.size)), initializer='ones', trainable=True)
        super(FPruningL, self).build(input_shape) 
    def call(self, x):
        ############################## 
        # TASK 1 write your code here
        return self.kernel1 * x
        ##############################
    def compute_output_shape(self, input_shape):
        return input_shape
    def get_config(self):
        return {'num': self.num}

# %% [markdown]
# # Task 2
#
# In this step we will create a new prunable network from the orignal netwok. We will place pruning custom layers infront of each CONV layer. To initialize custom layers we will pass the CONV layer filter number to these custom layers so that 1-D tensors of appropriate size can be initialized.
#
# In this task you will create a new prunable model named 'model2' from the orignal model. you will create this new model by looping through the layer of orignal model. Add all the layers of the orignal model to the new model while conditioning on 'Conv2D'. For 'Conv2D' find the number of filters and add the 'Conv2D' layer to the network then initialize 'FPruningL' layer by passing number of filters(e.g: FPruningL(filters)) to it. Add this FPruningL layer to the network. Your prunable networkhouk like this:Cell below
#
# Where CONV layer has a FPruningL infront of it

# %%
plot_model(model2)

# %%
# creating pruneable model from orignal model
##############################
# TASK 2 write your code here
model2 = Sequential()
for eachlayer in model.layers:
  model2.add(eachlayer)
  if eachlayer.name.split('_')[0] == 'conv2d':
    new_layer = FPruningL(eachlayer.filters)
    model2.add(new_layer)
##############################
model2.summary()
##############################
# Out:
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 64)        640
# _________________________________________________________________
# f_pruning_l_13 (FPruningL)   (None, 32, 32, 64)        64
# _________________________________________________________________
# activation_15 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# f_pruning_l_14 (FPruningL)   (None, 32, 32, 64)        64
# _________________________________________________________________
# activation_16 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# f_pruning_l_15 (FPruningL)   (None, 16, 16, 128)       128
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# f_pruning_l_16 (FPruningL)   (None, 16, 16, 128)       128
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# f_pruning_l_17 (FPruningL)   (None, 8, 8, 256)         256
# _________________________________________________________________
# activation_19 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# f_pruning_l_18 (FPruningL)   (None, 8, 8, 256)         256
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# f_pruning_l_19 (FPruningL)   (None, 8, 8, 256)         256
# _________________________________________________________________
# activation_21 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# f_pruning_l_20 (FPruningL)   (None, 4, 4, 512)         512
# _________________________________________________________________
# activation_22 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# f_pruning_l_21 (FPruningL)   (None, 4, 4, 512)         512
# _________________________________________________________________
# activation_23 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# f_pruning_l_22 (FPruningL)   (None, 4, 4, 512)         512
# _________________________________________________________________
# activation_24 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# f_pruning_l_23 (FPruningL)   (None, 2, 2, 512)         512
# _________________________________________________________________
# activation_25 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# f_pruning_l_24 (FPruningL)   (None, 2, 2, 512)         512
# _________________________________________________________________
# activation_26 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# f_pruning_l_25 (FPruningL)   (None, 2, 2, 512)         512
# _________________________________________________________________
# activation_27 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_28 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_29 (Activation)   (None, 10)                0
# =================================================================
# Total params: 15,004,490
# Trainable params: 14,995,018
# Non-trainable params: 9,472
# _________________________________________________________________

# %%
plot_model(model2)

# %% [markdown]
# We will create a callback function to monitor how many filters are dropable(i.e: there corrisponding pruning tensor value is below threash)

# %%
#Call back for Filter Drop info info
class MyCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    error = 0
    f = 0
    l = 0
    print('\n')
    for layer in model2.layers:
      if (type(layer)==FPruningL):
        w = layer.get_weights()
        f = np.count_nonzero(w[0] <= 0.005)
        l+=f
        print("Filters Dropable : ",f)
    print("Total Filters Dropable : ",l)

# %% [markdown]
# Compile and train prunable model.

# %%
sgd = SGD(lr=0.01, decay=lr_decay, momentum=0.9, nesterov=True)
model2.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
# Fit the model on the batches generated by datagen.flow().
model2.fit(datagen.flow(x_train, y_train,
                                batch_size=batch_size),
                  steps_per_epoch=x_train.shape[0] // batch_size,
                  epochs=maxepoches,
                  validation_data=(x_test, y_test),callbacks=[MyCallback()],verbose=1)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 467/468 [============================>.] - ETA: 0s - loss: 28.4998 - accuracy: 0.8689
#
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  0
# 468/468 [==============================] - 112s 240ms/step - loss: 28.4819 - accuracy: 0.8690 - val_loss: 26.4208 - val_accuracy: 0.1278
# Epoch 2/20
# 467/468 [============================>.] - ETA: 0s - loss: 15.2122 - accuracy: 0.9510
#
# Filters Dropable :  32
# Filters Dropable :  24
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  56
# 468/468 [==============================] - 88s 187ms/step - loss: 15.2046 - accuracy: 0.9510 - val_loss: 15.0525 - val_accuracy: 0.1741
# Epoch 3/20
# 467/468 [============================>.] - ETA: 0s - loss: 9.3461 - accuracy: 0.9573
#
# Filters Dropable :  52
# Filters Dropable :  50
# Filters Dropable :  30
# Filters Dropable :  32
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  164
# 468/468 [==============================] - 88s 187ms/step - loss: 9.3426 - accuracy: 0.9572 - val_loss: 12.4406 - val_accuracy: 0.1533
# Epoch 4/20
# 467/468 [============================>.] - ETA: 0s - loss: 6.5235 - accuracy: 0.9592
#
# Filters Dropable :  57
# Filters Dropable :  55
# Filters Dropable :  79
# Filters Dropable :  64
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  255
# 468/468 [==============================] - 87s 187ms/step - loss: 6.5215 - accuracy: 0.9592 - val_loss: 5.8848 - val_accuracy: 0.8629
# Epoch 5/20
# 467/468 [============================>.] - ETA: 0s - loss: 4.8214 - accuracy: 0.9624
#
# Filters Dropable :  57
# Filters Dropable :  55
# Filters Dropable :  93
# Filters Dropable :  71
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  276
# 468/468 [==============================] - 88s 187ms/step - loss: 4.8198 - accuracy: 0.9625 - val_loss: 5.0119 - val_accuracy: 0.6319
# Epoch 6/20
# 467/468 [============================>.] - ETA: 0s - loss: 3.6128 - accuracy: 0.9604
#
# Filters Dropable :  59
# Filters Dropable :  55
# Filters Dropable :  100
# Filters Dropable :  77
# Filters Dropable :  80
# Filters Dropable :  38
# Filters Dropable :  64
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  473
# 468/468 [==============================] - 87s 187ms/step - loss: 3.6120 - accuracy: 0.9603 - val_loss: 3.3639 - val_accuracy: 0.9206
# Epoch 7/20
# 467/468 [============================>.] - ETA: 0s - loss: 2.9134 - accuracy: 0.9618
#
# Filters Dropable :  60
# Filters Dropable :  55
# Filters Dropable :  104
# Filters Dropable :  87
# Filters Dropable :  122
# Filters Dropable :  88
# Filters Dropable :  98
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  614
# 468/468 [==============================] - 87s 187ms/step - loss: 2.9128 - accuracy: 0.9618 - val_loss: 3.5020 - val_accuracy: 0.6959
# Epoch 8/20
# 467/468 [============================>.] - ETA: 0s - loss: 2.3195 - accuracy: 0.9614
#
# Filters Dropable :  60
# Filters Dropable :  55
# Filters Dropable :  106
# Filters Dropable :  93
# Filters Dropable :  154
# Filters Dropable :  114
# Filters Dropable :  120
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  702
# 468/468 [==============================] - 88s 187ms/step - loss: 2.3189 - accuracy: 0.9614 - val_loss: 2.1682 - val_accuracy: 0.9258
# Epoch 9/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.7348 - accuracy: 0.9633
#
# Filters Dropable :  60
# Filters Dropable :  55
# Filters Dropable :  108
# Filters Dropable :  95
# Filters Dropable :  170
# Filters Dropable :  141
# Filters Dropable :  139
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  768
# 468/468 [==============================] - 87s 187ms/step - loss: 1.7341 - accuracy: 0.9633 - val_loss: 1.7329 - val_accuracy: 0.8803
# Epoch 10/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.1733 - accuracy: 0.9648
#
# Filters Dropable :  60
# Filters Dropable :  55
# Filters Dropable :  111
# Filters Dropable :  98
# Filters Dropable :  179
# Filters Dropable :  156
# Filters Dropable :  154
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Filters Dropable :  0
# Total Filters Dropable :  813
# 468/468 [==============================] - 87s 186ms/step - loss: 1.1726 - accuracy: 0.9648 - val_loss: 1.3721 - val_accuracy: 0.8864
# Epoch 11/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.6741 - accuracy: 0.9724
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  111
# Filters Dropable :  101
# Filters Dropable :  196
# Filters Dropable :  181
# Filters Dropable :  169
# Filters Dropable :  36
# Filters Dropable :  1
# Filters Dropable :  3
# Filters Dropable :  34
# Filters Dropable :  0
# Filters Dropable :  2
# Total Filters Dropable :  950
# 468/468 [==============================] - 87s 186ms/step - loss: 0.6738 - accuracy: 0.9724 - val_loss: 0.5137 - val_accuracy: 0.9763
# Epoch 12/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.4574 - accuracy: 0.9691
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  113
# Filters Dropable :  103
# Filters Dropable :  204
# Filters Dropable :  190
# Filters Dropable :  186
# Filters Dropable :  303
# Filters Dropable :  333
# Filters Dropable :  333
# Filters Dropable :  380
# Filters Dropable :  380
# Filters Dropable :  400
# Total Filters Dropable :  3041
# 468/468 [==============================] - 87s 185ms/step - loss: 0.4574 - accuracy: 0.9691 - val_loss: 0.4052 - val_accuracy: 0.9719
# Epoch 13/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3956 - accuracy: 0.9660
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  114
# Filters Dropable :  103
# Filters Dropable :  207
# Filters Dropable :  196
# Filters Dropable :  196
# Filters Dropable :  370
# Filters Dropable :  406
# Filters Dropable :  391
# Filters Dropable :  435
# Filters Dropable :  445
# Filters Dropable :  455
# Total Filters Dropable :  3434
# 468/468 [==============================] - 87s 185ms/step - loss: 0.3956 - accuracy: 0.9660 - val_loss: 0.6479 - val_accuracy: 0.8755
# Epoch 14/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3701 - accuracy: 0.9673
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  114
# Filters Dropable :  103
# Filters Dropable :  209
# Filters Dropable :  199
# Filters Dropable :  204
# Filters Dropable :  408
# Filters Dropable :  427
# Filters Dropable :  416
# Filters Dropable :  456
# Filters Dropable :  463
# Filters Dropable :  468
# Total Filters Dropable :  3583
# 468/468 [==============================] - 87s 185ms/step - loss: 0.3700 - accuracy: 0.9673 - val_loss: 0.3716 - val_accuracy: 0.9670
# Epoch 15/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3563 - accuracy: 0.9670
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  114
# Filters Dropable :  103
# Filters Dropable :  214
# Filters Dropable :  206
# Filters Dropable :  206
# Filters Dropable :  423
# Filters Dropable :  434
# Filters Dropable :  426
# Filters Dropable :  464
# Filters Dropable :  472
# Filters Dropable :  476
# Total Filters Dropable :  3654
# 468/468 [==============================] - 87s 185ms/step - loss: 0.3565 - accuracy: 0.9670 - val_loss: 0.4300 - val_accuracy: 0.9438
# Epoch 16/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3473 - accuracy: 0.9672
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  114
# Filters Dropable :  104
# Filters Dropable :  216
# Filters Dropable :  210
# Filters Dropable :  210
# Filters Dropable :  436
# Filters Dropable :  443
# Filters Dropable :  435
# Filters Dropable :  467
# Filters Dropable :  475
# Filters Dropable :  479
# Total Filters Dropable :  3705
# 468/468 [==============================] - 87s 185ms/step - loss: 0.3472 - accuracy: 0.9672 - val_loss: 0.5317 - val_accuracy: 0.9153
# Epoch 17/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3444 - accuracy: 0.9668
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  115
# Filters Dropable :  105
# Filters Dropable :  217
# Filters Dropable :  214
# Filters Dropable :  213
# Filters Dropable :  448
# Filters Dropable :  447
# Filters Dropable :  443
# Filters Dropable :  468
# Filters Dropable :  476
# Filters Dropable :  483
# Total Filters Dropable :  3746
# 468/468 [==============================] - 87s 185ms/step - loss: 0.3444 - accuracy: 0.9668 - val_loss: 1.2494 - val_accuracy: 0.6896
# Epoch 18/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.9672
#
# Filters Dropable :  60
# Filters Dropable :  56
# Filters Dropable :  115
# Filters Dropable :  105
# Filters Dropable :  219
# Filters Dropable :  216
# Filters Dropable :  213
# Filters Dropable :  453
# Filters Dropable :  450
# Filters Dropable :  446
# Filters Dropable :  470
# Filters Dropable :  480
# Filters Dropable :  484
# Total Filters Dropable :  3767
# 468/468 [==============================] - 87s 185ms/step - loss: 0.3389 - accuracy: 0.9672 - val_loss: 0.4847 - val_accuracy: 0.9266
# Epoch 19/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3387 - accuracy: 0.9664
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  214
# Filters Dropable :  459
# Filters Dropable :  455
# Filters Dropable :  447
# Filters Dropable :  472
# Filters Dropable :  480
# Filters Dropable :  484
# Total Filters Dropable :  3789
# 468/468 [==============================] - 86s 185ms/step - loss: 0.3387 - accuracy: 0.9664 - val_loss: 0.4344 - val_accuracy: 0.9408
# Epoch 20/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.3299 - accuracy: 0.9674
#
# Filters Dropable :  61
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  106
# Filters Dropable :  221
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  465
# Filters Dropable :  456
# Filters Dropable :  449
# Filters Dropable :  473
# Filters Dropable :  482
# Filters Dropable :  486
# Total Filters Dropable :  3807
# 468/468 [==============================] - 86s 185ms/step - loss: 0.3299 - accuracy: 0.9674 - val_loss: 0.3167 - val_accuracy: 0.9726

# %% [markdown]
# # Task 3

# %% [markdown]
# In this step we will zero out pruning tensor values that are below thresh and turn all values above threash to 1 to completly shut down the respective filters of prunable values.
#
# In this task you will loop through model2 and condition on FPruningL. You will get the weights of FPruningL layers, zero out pruning tensor values that are below thresh and turn all values above threash to 1 and set these updated weights to FPruningL layers. You will also make the FPruningL layers non-trainable.
#
# Threashold is : 0.0005
#
# Hint: see MyCallback().

# %%
# zero out scalling factor based on threashold
##############################
# TASK 3 Write your code here
for eachlayer in model2.layers:
  if eachlayer.name.split('_l')[0] == 'f_pruning':
    weightsLayers = eachlayer.get_weights()
    weightsLayers = np.where(weightsLayers[0] <= 0.0005,0,1)
    weightsLayers = np.expand_dims(weightsLayers,0)
    eachlayer.set_weights(weightsLayers)
    eachlayer.trainable = False
##############################

# %% [markdown]
# Till this step all of our prunable filters are theoratically pruned from the netwok but physically they are still a part of the network. To remove them physically run the notebook till end.

# %% [markdown]
# Now we will finetune this pruned network for a few epochs to reachive any drop in accuracy

# %%
sgd = SGD(lr=0.001, decay=lr_decay, momentum=0.9, nesterov=True)
model2.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
# Fit the model on the batches generated by datagen.flow().
model2.fit(datagen.flow(x_train, y_train,
                                batch_size=batch_size),
                  steps_per_epoch=x_train.shape[0] // batch_size,
                  epochs=maxepoches,
                  validation_data=(x_test, y_test),callbacks=[MyCallback()],verbose=1)
# Out:
# Epoch 1/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.6319 - accuracy: 0.9778
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 100s 215ms/step - loss: 1.6317 - accuracy: 0.9779 - val_loss: 1.5709 - val_accuracy: 0.9895
# Epoch 2/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5849 - accuracy: 0.9832
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 184ms/step - loss: 1.5850 - accuracy: 0.9832 - val_loss: 1.5569 - val_accuracy: 0.9897
# Epoch 3/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5693 - accuracy: 0.9844
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 183ms/step - loss: 1.5692 - accuracy: 0.9844 - val_loss: 1.5497 - val_accuracy: 0.9877
# Epoch 4/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5575 - accuracy: 0.9852
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 185ms/step - loss: 1.5575 - accuracy: 0.9852 - val_loss: 1.5393 - val_accuracy: 0.9897
# Epoch 5/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5501 - accuracy: 0.9845
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 184ms/step - loss: 1.5501 - accuracy: 0.9846 - val_loss: 1.5265 - val_accuracy: 0.9903
# Epoch 6/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5397 - accuracy: 0.9854
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 183ms/step - loss: 1.5397 - accuracy: 0.9854 - val_loss: 1.5241 - val_accuracy: 0.9898
# Epoch 7/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5336 - accuracy: 0.9858
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 185ms/step - loss: 1.5335 - accuracy: 0.9858 - val_loss: 1.5236 - val_accuracy: 0.9882
# Epoch 8/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5245 - accuracy: 0.9864
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 87s 186ms/step - loss: 1.5246 - accuracy: 0.9864 - val_loss: 1.5124 - val_accuracy: 0.9899
# Epoch 9/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5188 - accuracy: 0.9862
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 87s 185ms/step - loss: 1.5188 - accuracy: 0.9862 - val_loss: 1.5239 - val_accuracy: 0.9831
# Epoch 10/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5160 - accuracy: 0.9862
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 87s 185ms/step - loss: 1.5159 - accuracy: 0.9862 - val_loss: 1.5210 - val_accuracy: 0.9834
# Epoch 11/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5127 - accuracy: 0.9861
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 87s 186ms/step - loss: 1.5128 - accuracy: 0.9861 - val_loss: 1.5030 - val_accuracy: 0.9893
# Epoch 12/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5074 - accuracy: 0.9861
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 87s 185ms/step - loss: 1.5075 - accuracy: 0.9860 - val_loss: 1.5001 - val_accuracy: 0.9881
# Epoch 13/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5037 - accuracy: 0.9862
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 86s 184ms/step - loss: 1.5036 - accuracy: 0.9862 - val_loss: 1.5054 - val_accuracy: 0.9847
# Epoch 14/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5036 - accuracy: 0.9857
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 182ms/step - loss: 1.5036 - accuracy: 0.9857 - val_loss: 1.4907 - val_accuracy: 0.9893
# Epoch 15/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.5001 - accuracy: 0.9862
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 181ms/step - loss: 1.5002 - accuracy: 0.9862 - val_loss: 1.5032 - val_accuracy: 0.9827
# Epoch 16/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.4980 - accuracy: 0.9855
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 182ms/step - loss: 1.4979 - accuracy: 0.9855 - val_loss: 1.4866 - val_accuracy: 0.9893
# Epoch 17/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.4972 - accuracy: 0.9858
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 182ms/step - loss: 1.4972 - accuracy: 0.9858 - val_loss: 1.4878 - val_accuracy: 0.9882
# Epoch 18/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.4974 - accuracy: 0.9854
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 181ms/step - loss: 1.4974 - accuracy: 0.9854 - val_loss: 1.4900 - val_accuracy: 0.9883
# Epoch 19/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.4930 - accuracy: 0.9861
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 181ms/step - loss: 1.4930 - accuracy: 0.9861 - val_loss: 1.4839 - val_accuracy: 0.9876
# Epoch 20/20
# 467/468 [============================>.] - ETA: 0s - loss: 1.4915 - accuracy: 0.9860
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 85s 181ms/step - loss: 1.4916 - accuracy: 0.9860 - val_loss: 1.4884 - val_accuracy: 0.9871

# %% [markdown]
# Now we will remove our custom pruning layers from the network and save the pruning info from these layers in lists to use later for the removal of redundent filters.

# %%
#removing Pruning Layers
la = model2.layers
inputl = Input(shape=(model2.input_shape[1:]))
model3 = inputl

i = 0
while(i < len(la)):
  layer = la[i]
  if(type(layer)==Conv2D):
    c = layer
    if (type(la[i+1])==FPruningL):
      v = c.get_weights()
      v[0] = la[i+1].get_weights()[0]*v[0]
      c.set_weights(v)
      model3 = (c)(model3)

    else:
      model3 = (c)(model3)
  elif(type(layer)==InputLayer):
    print("")
  else:
    model3 = (layer)(model3)
    if(type(layer)==BatchNormalization):
      print("")
  i+=1
model3 = Model(inputs=[inputl], outputs=model3)
# Out:
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c07ec90>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c2f5510>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7c034410>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a715190>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a671e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a6a8d10>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a639c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a5ab990>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4aeb90>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a4ae6d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3cae50>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a3bf750>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
# WARNING:tensorflow:Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method FPruningL.call of <__main__.FPruningL object at 0x7fad7a26b590>>: AssertionError: Bad argument number for Name: 3, expecting 4

# %%
#removing BN to use keras sergeon for filter pruning
la = model3.layers
inputl = Input(shape=(model2.input_shape[1:]))
model4 = inputl
i = 0
w = []
b = []
while(i < len(la)):
  layer = la[i]
  if(type(layer)==FPruningL):
    w.append(layer.get_weights()[0][0][0][0])
  elif(type(layer)==InputLayer):
    print("")
  elif(type(layer)==BatchNormalization):
    b.append(layer.get_weights())
  else:
    model4 = (layer)(model4)
  i+=1
model4 = Model(inputs=[inputl], outputs=model4)

# %%
#BN heandling
wx = []
for i in range(0,len(w)):
  wx.append(w[i].astype(bool))

# %%
#BN heandling
for i in range(0,len(wx)):
  b[i][0]=b[i][0][wx[i]]
  b[i][1]=b[i][1][wx[i]]
  b[i][2]=b[i][2][wx[i]]
  b[i][3]=b[i][3][wx[i]]

# %%
#Filter pruning info handling
w2 = []
for i in range(0,len(w)):
  s = w[i].shape
  c = 0
  for j in range(0,s[0]):
    if(w[i][j]==0):
      c+=1
  k = np.zeros(c)
  l = 0
  for j in range(0,s[0]):
    if(w[i][j]==0):
      k[l]=j
      l+=1
  w2.append(k)

# %%
# !pip install tfkerassurgeon
# Out:
# Collecting tfkerassurgeon
#   Downloading https://files.pythonhosted.org/packages/10/a1/3d4cd1b8d8c9289cb26e2c568493d40c1b6b15a35a54a8ed96a4c5c7f5ba/tfkerassurgeon-0.2.1.tar.gz
# Building wheels for collected packages: tfkerassurgeon
#   Building wheel for tfkerassurgeon (setup.py) ... done
#   Created wheel for tfkerassurgeon: filename=tfkerassurgeon-0.2.1-cp37-none-any.whl size=22026 sha256=71626814a8af20016f47d3fd9cfc0248a6aa9fa512a3302e079b51a3dc030189
#   Stored in directory: /root/.cache/pip/wheels/33/41/28/daca963a6834fecf8cd9a3b207288ba325fdf012a7ebd95715
# Successfully built tfkerassurgeon
# Installing collected packages: tfkerassurgeon
# Successfully installed tfkerassurgeon-0.2.1

# %%
from tfkerassurgeon.surgeon import Surgeon

# %%
surgeon = Surgeon(model4, None)
i = 0
for layer in model4.layers:
  if(type(layer)==Conv2D):
    w2[i] = w2[i].astype(int)
    s = w2[i].shape
    if(s[0]!=0):  
      surgeon.add_job('delete_channels', layer, node_indexes=None, channels=w2[i])
    i+=1

# %%
new_model = surgeon.operate()
# Out:
# Deleting 60/64 channels from layer: conv2d_13
# Deleting 57/64 channels from layer: conv2d_14
# Deleting 116/128 channels from layer: conv2d_15
# Deleting 105/128 channels from layer: conv2d_16
# Deleting 220/256 channels from layer: conv2d_17
# Deleting 220/256 channels from layer: conv2d_18
# Deleting 215/256 channels from layer: conv2d_19
# Deleting 464/512 channels from layer: conv2d_20
# Deleting 455/512 channels from layer: conv2d_21
# Deleting 449/512 channels from layer: conv2d_22
# Deleting 472/512 channels from layer: conv2d_23
# Deleting 482/512 channels from layer: conv2d_24
# Deleting 484/512 channels from layer: conv2d_25

# %%
#readding BN
la = model3.layers
inputl = Input(shape=(model2.input_shape[1:]))
model5 = inputl
i = 0
for layer in new_model.layers:
  if(type(layer)==Activation and i<len(b)):
    model5 = (layer)(model5)
    model5 = (BatchNormalization())(model5)
    i+=1
  else:
    model5 = (layer)(model5)
model5 = Model(inputs=[inputl], outputs=model5)

# %%
#Adding weights to BN
i = 0
for layer in model5.layers:
  if(type(layer)==BatchNormalization):
    layer.set_weights(b[i])
    i+=1

# %%
def count_conv_params_flops(conv_layer, verbose=0):
    # out shape is  n_cells_dim1 * (n_cells_dim2 * n_cells_dim3)
    out_shape = conv_layer.output.shape.as_list()
    n_cells_total = np.prod(out_shape[1:-1])

    n_conv_params_total = conv_layer.count_params()

    conv_flops = 2 * n_conv_params_total * n_cells_total

    if verbose:
        print("layer %s params: %s" % (conv_layer.name, "{:,}".format(n_conv_params_total)))
        print("layer %s flops: %s" % (conv_layer.name, "{:,}".format(conv_flops)))

    return n_conv_params_total, conv_flops


def count_dense_params_flops(dense_layer, verbose=0):
    # out shape is  n_cells_dim1 * (n_cells_dim2 * n_cells_dim3)
    out_shape = dense_layer.output.shape.as_list()
    n_cells_total = np.prod(out_shape[1:-1])

    n_dense_params_total = dense_layer.count_params()

    dense_flops = 2 * n_dense_params_total

    if verbose:
        print("layer %s params: %s" % (dense_layer.name, "{:,}".format(n_dense_params_total)))
        print("layer %s flops: %s" % (dense_layer.name, "{:,}".format(dense_flops)))

    return n_dense_params_total, dense_flops


def count_model_params_flops(model):
    total_params = 0
    total_flops = 0

    model_layers = model.layers

    for layer in model_layers:

        if any(conv_type in str(type(layer)) for conv_type in ['Conv1D', 'Conv2D', 'Conv3D']):
            params, flops = count_conv_params_flops(layer)
            total_params += params
            total_flops += flops
        elif 'Dense' in str(type(layer)):
            params, flops = count_dense_params_flops(layer)
            total_params += params
            total_flops += flops
        # else:
        #     print("warning:: skippring layer: %s" % str(layer))

    print("total params (%s) : %s" % (model.name, "{:,}".format(total_params)))
    print("total flops  (%s) : %s" % (model.name, "{:,}".format(total_flops)))

    return total_params, total_flops

# %%
count_model_params_flops(model)
# Out:
# total params (sequential_4) : 14,981,322
# total flops  (sequential_4) : 625,122,324
# (14981322, 625122324)

# %%
count_model_params_flops(model5)
# Out:
# total params (model_3) : 172,026
# total flops  (model_3) : 9,214,212
# (172026, 9214212)

# %%
sgd = SGD(lr=0.001, decay=lr_decay, momentum=0.9, nesterov=True)
model5.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
# Fit the model on the batches generated by datagen.flow().
model5.fit(datagen.flow(x_train, y_train,
                                batch_size=batch_size),
                  steps_per_epoch=x_train.shape[0] // batch_size,
                  epochs=maxepoches,
                  validation_data=(x_test, y_test),callbacks=[MyCallback()],verbose=1)
# Out:
# Epoch 1/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9858
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 52s 112ms/step - loss: 0.0857 - accuracy: 0.9858 - val_loss: 0.0799 - val_accuracy: 0.9865
# Epoch 2/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0859 - accuracy: 0.9853
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 39s 83ms/step - loss: 0.0859 - accuracy: 0.9854 - val_loss: 0.0864 - val_accuracy: 0.9837
# Epoch 3/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0853 - accuracy: 0.9849
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 81ms/step - loss: 0.0852 - accuracy: 0.9849 - val_loss: 0.0737 - val_accuracy: 0.9889
# Epoch 4/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9857
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 80ms/step - loss: 0.0840 - accuracy: 0.9857 - val_loss: 0.0815 - val_accuracy: 0.9861
# Epoch 5/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0830 - accuracy: 0.9855
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 80ms/step - loss: 0.0830 - accuracy: 0.9855 - val_loss: 0.1009 - val_accuracy: 0.9797
# Epoch 6/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0836 - accuracy: 0.9852
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 80ms/step - loss: 0.0836 - accuracy: 0.9852 - val_loss: 0.0859 - val_accuracy: 0.9861
# Epoch 7/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0853 - accuracy: 0.9851
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 39s 83ms/step - loss: 0.0852 - accuracy: 0.9851 - val_loss: 0.0857 - val_accuracy: 0.9842
# Epoch 8/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0842 - accuracy: 0.9847
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 80ms/step - loss: 0.0842 - accuracy: 0.9847 - val_loss: 0.0799 - val_accuracy: 0.9879
# Epoch 9/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0832 - accuracy: 0.9850
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 80ms/step - loss: 0.0832 - accuracy: 0.9851 - val_loss: 0.0773 - val_accuracy: 0.9870
# Epoch 10/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0864 - accuracy: 0.9841
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0864 - accuracy: 0.9841 - val_loss: 0.0706 - val_accuracy: 0.9882
# Epoch 11/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9856
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 80ms/step - loss: 0.0831 - accuracy: 0.9856 - val_loss: 0.0766 - val_accuracy: 0.9875
# Epoch 12/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9849
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 80ms/step - loss: 0.0831 - accuracy: 0.9849 - val_loss: 0.0752 - val_accuracy: 0.9869
# Epoch 13/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9856
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0829 - accuracy: 0.9856 - val_loss: 0.0768 - val_accuracy: 0.9866
# Epoch 14/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0830 - accuracy: 0.9850
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0829 - accuracy: 0.9850 - val_loss: 0.0830 - val_accuracy: 0.9853
# Epoch 15/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0809 - accuracy: 0.9859
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0809 - accuracy: 0.9860 - val_loss: 0.0693 - val_accuracy: 0.9899
# Epoch 16/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9854
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0827 - accuracy: 0.9854 - val_loss: 0.0795 - val_accuracy: 0.9869
# Epoch 17/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0802 - accuracy: 0.9861
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0803 - accuracy: 0.9860 - val_loss: 0.0865 - val_accuracy: 0.9843
# Epoch 18/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9856
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 80ms/step - loss: 0.0806 - accuracy: 0.9855 - val_loss: 0.0827 - val_accuracy: 0.9856
# Epoch 19/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9862
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 37s 79ms/step - loss: 0.0806 - accuracy: 0.9862 - val_loss: 0.0861 - val_accuracy: 0.9862
# Epoch 20/20
# 467/468 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9853
#
# Filters Dropable :  60
# Filters Dropable :  57
# Filters Dropable :  116
# Filters Dropable :  105
# Filters Dropable :  220
# Filters Dropable :  220
# Filters Dropable :  215
# Filters Dropable :  464
# Filters Dropable :  455
# Filters Dropable :  449
# Filters Dropable :  472
# Filters Dropable :  482
# Filters Dropable :  484
# Total Filters Dropable :  3799
# 468/468 [==============================] - 38s 80ms/step - loss: 0.0824 - accuracy: 0.9853 - val_loss: 0.0641 - val_accuracy: 0.9911
